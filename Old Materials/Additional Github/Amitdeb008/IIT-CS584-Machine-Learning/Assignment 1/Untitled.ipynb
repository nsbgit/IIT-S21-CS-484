# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#                                          CS 584 Assignment 1                                                 "
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Amitdeb Prasad Bhattacharya"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## A20402789"
   ]
  },
# Out:
#   File "<ipython-input-3-7f4baf7c192e>", line 2
#     "cells": [
#     ^
# IndentationError: unexpected indent
